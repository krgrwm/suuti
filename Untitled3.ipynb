# %%
scatter(res[1, 1:pd:end-1], t[2, 1:pd:end-1], s=scale)
# Out:
# Figure(PyObject <matplotlib.figure.Figure object at 0x7f0c1547af60>)
# PyObject <matplotlib.collections.PathCollection object at 0x7f0c15453f98>
